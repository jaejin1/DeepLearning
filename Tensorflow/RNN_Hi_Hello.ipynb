# %%
# Lab 12 RNN
import tensorflow as tf
import numpy as np
tf.set_random_seed(777)  # reproducibility

# %%
idx2char = ['h', 'i', 'e', 'l', 'o']
# Teach hello: hihell -> ihello
x_data = [[0, 1, 0, 2, 3, 3]]   # hihell
x_one_hot = [[[1, 0, 0, 0, 0],   # h 0
              [0, 1, 0, 0, 0],   # i 1
              [1, 0, 0, 0, 0],   # h 0
              [0, 0, 1, 0, 0],   # e 2
              [0, 0, 0, 1, 0],   # l 3
              [0, 0, 0, 1, 0]]]  # l 3

y_data = [[1, 0, 2, 3, 3, 4]]    # ihello

num_classes = 5
input_dim = 5  # one-hot size
hidden_size = 5  # output from the LSTM. 5 to directly predict one-hot
batch_size = 1   # one sentence
sequence_length = 6  # |ihello| == 6
learning_rate = 0.1

# %%
X = tf.placeholder(
    tf.float32, [None, sequence_length, input_dim])  # X one-hot   Batch size , sequence size, input dim
Y = tf.placeholder(tf.int32, [None, sequence_length])  # Y label

cell = tf.contrib.rnn.BasicLSTMCell(num_units=hidden_size, state_is_tuple=True)
initial_state = cell.zero_state(batch_size, tf.float32)
outputs, _states = tf.nn.dynamic_rnn(
    cell, X, initial_state=initial_state, dtype=tf.float32)

# %%
# FC layer
print(X)
X_for_fc = tf.reshape(outputs, [-1, hidden_size])  # batch 없애기
print(X_for_fc)
# fc_w = tf.get_variable("fc_w", [hidden_size, num_classes])
# fc_b = tf.get_variable("fc_b", [num_classes])
# outputs = tf.matmul(X_for_fc, fc_w) + fc_b
outputs = tf.contrib.layers.fully_connected(
    inputs=X_for_fc, num_outputs=num_classes, activation_fn=None)

# reshape out for sequence_loss
outputs = tf.reshape(outputs, [batch_size, sequence_length, num_classes])

weights = tf.ones([batch_size, sequence_length])# weights 는 보통 1로함

sequence_loss = tf.contrib.seq2seq.sequence_loss(
    logits=outputs, targets=Y, weights=weights) 

loss = tf.reduce_mean(sequence_loss)
train = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(loss)

prediction = tf.argmax(outputs, axis=2)
# Out:
# Tensor("Placeholder:0", shape=(?, 6, 5), dtype=float32)
# Tensor("Reshape_8:0", shape=(6, 5), dtype=float32)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(50):
        l, _ = sess.run([loss, train], feed_dict={X: x_one_hot, Y: y_data})
        result = sess.run(prediction, feed_dict={X: x_one_hot})
        print(i, "loss:", l, "prediction: ", result, "true Y: ", y_data)

        # print char using dic
        result_str = [idx2char[c] for c in np.squeeze(result)]
        print("\tPrediction str: ", ''.join(result_str))
# Out:
# 0 loss: 1.6078 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 1 loss: 1.48062 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 2 loss: 1.36546 prediction:  [[3 3 3 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  llllll
# 3 loss: 1.21067 prediction:  [[2 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ehelll
# 4 loss: 1.03451 prediction:  [[2 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ehelll
# 5 loss: 0.877502 prediction:  [[2 0 2 3 3 3]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ehelll
# 6 loss: 0.764036 prediction:  [[2 0 2 3 4 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  eheloo
# 7 loss: 0.683623 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 8 loss: 0.57997 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 9 loss: 0.494565 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 10 loss: 0.414768 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 11 loss: 0.337018 prediction:  [[2 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ehello
# 12 loss: 0.278016 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 13 loss: 0.213319 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 14 loss: 0.153077 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 15 loss: 0.097547 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 16 loss: 0.0768844 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 17 loss: 0.0305581 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 18 loss: 0.0211888 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 19 loss: 0.0127977 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 20 loss: 0.00560026 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 21 loss: 0.00258241 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 22 loss: 0.00169505 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 23 loss: 0.00162607 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 24 loss: 0.00192706 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 25 loss: 0.00233359 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 26 loss: 0.00255846 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 27 loss: 0.00241263 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 28 loss: 0.00196779 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 29 loss: 0.00144549 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 30 loss: 0.00100087 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 31 loss: 0.000673568 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 32 loss: 0.000447836 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 33 loss: 0.000297906 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 34 loss: 0.000201187 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 35 loss: 0.000139886 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 36 loss: 0.000101275 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 37 loss: 7.69229e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 38 loss: 6.13491e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 39 loss: 5.13369e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 40 loss: 4.47613e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 41 loss: 4.04503e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 42 loss: 3.75895e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 43 loss: 3.57419e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 44 loss: 3.45299e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 45 loss: 3.36955e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 46 loss: 3.31988e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 47 loss: 3.28412e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 48 loss: 3.26027e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
# 49 loss: 3.2404e-05 prediction:  [[1 0 2 3 3 4]] true Y:  [[1, 0, 2, 3, 3, 4]]
# 	Prediction str:  ihello
